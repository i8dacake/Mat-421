# %% [markdown]
# <a href="https://colab.research.google.com/github/i8dacake/Mat-421/blob/main/ModuleH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **22. Ordinary Differential Equation - Initial Value Problems**

# %% [markdown]
# What are **differential equations**?
# They are relationships between a funtion and its derivatives. They can be used to model systems in every STEM field. We know that finding exact solutions to these equations can be difficult whereas for differentiation, analytical solutions can be computed. Therefore, numerical solutions are crucial to make these equations useful for designing and understanding systems.

# %% [markdown]
# ## **22.1 ODE Initial Value Problem Statement**

# %% [markdown]
# A **differential equation** is a relationship between a function, f(x), its independent variable, x, and any number of its derivatives. Differential equations can be categorised into two types: ordinary and partial equations.
#
# An **ordinary differential equation** or ODE is a differential equation where the independent variable, and the derivatives, are in one dimension. For an example of an ODE, consider a pendulum of length 𝑙 with a mass, 𝑚, at its end. So, $ml\frac{d^2\Theta(t)}{dt^2} = -mg \sin(\Theta(t))$, is the angle the pendulum makes with the vertical axis over time, Θ(𝑡), in the presence of vertical gravity, 𝑔.
#
# A **partial differentiation equation** or PDE is  a general form differential equation where 𝑥 is a vector containing the independent variables $x_1, x_2, x_3, \ldots, x_m$, and the partial derivatives can be of any order and with respect to any combination of variables. An example of a PDE would be the heat equation which describes the evolution of temperature in space over time. So, $\frac{\partial u(t, x, y, z)}{\partial t} = \alpha\left(\frac{\partial u(t, x, y, z)}{\partial x} + \frac{\partial u(t, x, y, z)}{\partial y} + \frac{\partial u(t, x, y, z)}{\partial z}\right)$, where 𝑢(𝑡,𝑥,𝑦,𝑧) is the  (𝑥,𝑦,𝑧) at time 𝑡, and 𝛼 is a thermal diffusion constant.$
#
# An equation is referred to as the $n^{\mathrm{th}}$ order ODE where n is the **order** of differential equation. For example, a differential equation can be written as $F\left(x, f(x), \frac{df(x)}{dx}, \frac{d^2f(x)}{dx^2}, \frac{d^3f(x)}{dx^3}, \ldots, \frac{d^{n-1}f(x)}{dx^{n-1}}\right) = \frac{d^{n}f(x)}{dx^{n}}.$
#
# A **general solution** to a differential equation is a 𝑔(𝑥) that satisfies the differential equation. For an ODE of order 𝑛, a **particular solution** is a 𝑝(𝑥) that satisfies the differential equation and n explicitly **known values** of the solution, or its derivatives, at certain points.
#
# A common set of known values for an ODE solution is the **initial value**. Finding a solution to an ODE given an initial value is called the **initial value problem**.

# %% [markdown]
# ## **22.2 Reduction of Order**

# %% [markdown]
# There are numerous numerical methods available to solve initial value problems, however, there is a catch. They are designed to particularly solve first-order differential equations. In order to solve higher order differential equations, the order of the differential equation in question must be reduced to first order. When we reduce the order of an ODE to first order, it can result in multiple variables. But since the derivatives are still taken with respect to the same independent variable, the ordinariness of the differential equation is retained.

# %% [markdown]
# ***A simple model to describe the change in population of rabbits, 𝑟(𝑡), and wolves, 𝑤(𝑡), might be $\frac{dr(t)}{dt} = 4r(t) - 2w(t)  and $$\frac{dw(t)}{dt} = r(t) + w(t)$. Write this system of differential equations as an equivalent differential equation in 𝑆(𝑡).***
#
# $\begin{split}
# S(t) =\left[\begin{array}{c}
# r(t) \\
# w(t)
# \end{array}\right].
# \end{split}$
#
# This first order ODE is equivalent to the pair of ODEs.
# $\begin{split}
# \frac{dS(t)}{dt} = \left[\begin{array}{cc}
# 4 & -2 \\
# 1 & 1
# \end{array}\right]S(t).
# \end{split}$

# %% [markdown]
# ## **22.3 The Euler Method**

# %% [markdown]
# The **Explicit Euler Formula** is $S(t_{j+1}) = S(t_j) + hF(t_j, S(t_j))$. It allows us to compute an approximation for the state at $S(t_{j+1})$ given the state at $S(t_j)$.

# %% [markdown]
# ***The differential equation $\frac{df(t)}{dt} = e^{-t}$ with initial condition $𝑓_0 = −1$ has the exact solution $f(t) = -e^{-t}$. Approximate the solution to this initial value problem between 0 and 1 in increments of 0.1 using the Explicity Euler Formula. Plot the difference between the approximated solution and the exact solution.***

# %%
import numpy as np
import matplotlib.pyplot as plt

# Defining parameters.
f = lambda t, s: np.exp(-t) # This is the ODE.
h = 0.1 # Step size.
t = np.arange(0, 1 + h, h) # Numerical grid.
s0 = -1 # Initial Condition.

# Explicit Euler Method.
s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) - 1):
    s[i + 1] = s[i] + h*f(t[i], s[i])

plt.figure(figsize = (4, 4))
plt.plot(t, s, 'bo--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution \
for Simple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Repeating the above process for $h = 0.01$, we can get a better approximation of the solution on the numerical grid.. we can see each dot is one approximation based on the previous dot in a linear fashion.

# %%
h = 0.01 # Step size.
t = np.arange(0, 1 + h, h) # Numerical grid.
s0 = -1 # Initial Condition.

# Explicit Euler Method.
s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) - 1):
    s[i + 1] = s[i] + h*f(t[i], s[i])

plt.figure(figsize = (4, 4))
plt.plot(t, s, 'b--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution \
for Simple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()
