# %% [markdown]
# <a href="https://colab.research.google.com/github/i8dacake/Mat-421/blob/main/ModuleE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **3.1 Introduction**

# %% [markdown]
# There is a need to study algorithms to develop a comprehensive understanding of how an objective function with respect to a set of desired model parameters that control how well a model can explain its data can be optimized. Such optimization problems require concepts from calculus such as continuity, differentiation, taylor's theorem, amongst the others.

# %% [markdown]
# # **3.2 Continuity and Differentiation**

# %% [markdown]
# What is a **continuous** function? A continuous function is a function that does not contain any discontinuities. Let f : D → R be a real-valued function on D ⊆ $R^d$. Then f is said to be continuous at a ∈ D if lim f(x) as x → a = f(a).
#
# What is the **limit** of a function? Let f : D → R be a real-valued function on D ⊆ $R^d$. Then f is said to have a limit L ∈ R as x approaches a if : for any ε > 0, there exists a δ > 0 such that | f (x) − L| < ε for all x ∈ D ∩ Bδ (a) \ {a}.
#
# What is the **composition** of continuous functions? Let f : D1 → $R^m$, where D1 ⊆ $R^d$, and let g : D2 → $R^p$, where D2 ⊆ $R^m$. Assume that f is continuous at x0 and that g is continuous f(x0). Then g ◦ f is continuous at x0.
#
# What is **extremum**? Suppose f : D → R is defined on a set D ⊆ $R^d$. We say that f attains a maximum value M at z ∗ if f(z∗)= M and M ≥ f(x) for all x ∈ D. Similarly, we say f attains a minimum value m at z∗ if f(z∗) = m and m ≤ f(x) for all x ∈ D.
#
# What is **extreme value**? Let f : D → R be a real-valued, continuous function on a nonempty, closed, bounded set D ⊆ $R^d$. Then f attains a maximum and a minimum on D.
#
# What is a **derivative**? The derivative of a function of a real variable measures the sensitivity to change of the function value with respect to another variable.
#
# What is the **mean value** theorem? Let f : [a, b] → R be a continuous function and assume that its derivative exists on (a, b). Then there is a < c < b such that f(b) = f(a) + (b − a) * f'(c).
#
# What is **gradient descent**? Gradient descent is an iterative optimization algorithm for finding a local minimum of a differentiable function.

# %% [markdown]
# ***Consider the function 𝑓(𝑥) = cos(𝑥) and compute the derivatives numerically.***

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# step size
h = 0.1
# defining grid
x = np.arange(0, 2*np.pi, h)
# computing function
y = np.cos(x)

# computing vector of forward differences
forward_diff = np.diff(y)/h
# computing corresponding grid
x_diff = x[:-1:]
# computing exact solution
exact_solution = -np.sin(x_diff)

plt.figure(figsize = (4, 4))
plt.plot(x_diff, forward_diff, '--', \
         label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, \
        label = 'Exact solution')
plt.show()

max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# 0.049984407218554114

# %% [markdown]
# The finite difference approximation is represented by the blue dotted line and the exact solution by the orange line.

# %% [markdown]
# ***Consider the function f(x) = $x^2$ + 3x + 4. Find the value of x that minimizes the function.***

# %%
def gradient_descent(start, rate, n):
    x = start
    for _ in range(n):
        gradient = 2 * x + 3
        x = x - rate * gradient
    return x

start = 0
rate = 0.1
n = 100

minx = gradient_descent(start, rate, n)

print(f"Min x: {min_x}")
print(f"Value at x: {min_x**2 + 3*min_x + 4}")
# Out:
# Min x: -1.4999999996944446
# Value at x: 1.75

# %% [markdown]
# We can observe that the minimum of the function is approximately at x = -1.5 and at this point, the value of the function at x = 1.75.

# %% [markdown]
# # **3.3 Taylor's Theorem**

# %% [markdown]
# What is **Taylor’s theorem**? It gives an approximation of a differentiable function around a given point by a polynomial.

# %% [markdown]
# ***Use Python to plot the sin function along with the first, third, fifth, and seventh order Taylor series approximations.***

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))

labels = ['First Order', 'Third Order', 'Fifth Order', 'Seventh Order']

plt.figure(figsize = (6,6))
for n, label in zip(range(4), labels):
    y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)
    plt.plot(x,y, label = label)

plt.plot(x, np.sin(x), 'k', label = 'Analytic')
plt.grid()
plt.title('Taylor Series Approximations of Various Orders')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# <ipython-input-15-891ca7a3f3c3>:11: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)

# %% [markdown]
# ***Compute the seventh order Taylor series approximation for 𝑠𝑖𝑛(𝑥) around 𝑎 = 0 at 𝑥 = 𝜋/2. Compare the value to the correct value, 1.***

# %%
x = np.pi/2
y = 0

for n in range(4):
    y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)

print(y)
# Out:
# 0.9998431013994987
# <ipython-input-16-0adc46e5be05>:5: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)

# %% [markdown]
# We can observe that the computed value is very close to the theoretical value.
